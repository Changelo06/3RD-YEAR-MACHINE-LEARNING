# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.19.0

# %%
 # Create a scalar (rank 0 tensor)
 scalar = tf.constant(10)
 scalar
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=10>

# %%
# Create a rank 4 tensor (4 dimensions)
rank_4_tensor = tf.zeros([2, 3, 4, 5])
rank_4_tensor
rank_4_tensor.shape, rank_4_tensor.ndim, tf.size(rank_4_tensor)
# Out:
# (TensorShape([2, 3, 4, 5]), 4, <tf.Tensor: shape=(), dtype=int32, numpy=120>)

# %%
# Get various attributes of tensor
print("Datatype of every element:", rank_4_tensor.dtype)
print("Number of dimensions (rank):", rank_4_tensor.ndim)
print("Shape of tensor:", rank_4_tensor.shape)
print("Elements along axis 0 of tensor:", rank_4_tensor.shape[0])
print("Elements along last axis of tensor:", rank_4_tensor.shape[-1])
print("Total number of elements (2*3*4*5):", tf.size(rank_4_tensor).numpy()) 
#numpy() converts to NumPy array
# Out:
# Datatype of every element: <dtype: 'float32'>
# Number of dimensions (rank): 4
# Shape of tensor: (2, 3, 4, 5)
# Elements along axis 0 of tensor: 2
# Elements along last axis of tensor: 5
# Total number of elements (2*3*4*5): 120

# %%
import tensorflow as tf
print(tf.__version__) # check the version (should be 2.x+)
import datetime
print(f"Notebook last run (end-to-end): {datetime.datetime.now()}")
# Out:
# 2.19.0
# Notebook last run (end-to-end): 2025-04-15 09:23:51.836670

# %%
import numpy as np
import matplotlib.pyplot as plt
# Create features
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])
# Create labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])
# Visualize it
plt.scatter(X, y)
plt.grid();

# %%
# Example input and output shapes of a regression model
house_info = tf.constant(["bedroom", "bathroom", "garage"])
house_price = tf.constant([939700])
house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700])>)

# %%
house_info.shape
# Out:
# TensorShape([3])

# %%
# Take a single example of X
input_shape = X[0].shape
# Take a single example of y
output_shape = y[0].shape
input_shape, output_shape # these are both scalars (no shape)
# Out:
# ((), ())

# %%
# Let's take a look at the single examples invidually
X[0], y[0]
# Out:
# (-7.0, 3.0)

# %%
import tensorflow as tf

# Set random seed
tf.random.set_seed(42)

# Dummy data (for testing only)
import numpy as np
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, input_shape=[1], activation='relu'),
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(
    loss=tf.keras.losses.mae,  # Mean Absolute Error
    optimizer=tf.keras.optimizers.SGD(),  # Stochastic Gradient Descent
    metrics=["mae"]
)

# Fit the model
model.fit(tf.expand_dims(X, axis=-1), y, epochs=100, verbose = 1 )
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 13.9196 - mae: 13.9196
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 13.5554 - mae: 13.5554
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 13.1901 - mae: 13.1901
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 12.8203 - mae: 12.8203
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 12.4427 - mae: 12.4427
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 12.0537 - mae: 12.0537
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 11.6499 - mae: 11.6499
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 11.2275 - mae: 11.2275
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 10.7826 - mae: 10.7826
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - loss: 10.3111 - mae: 10.3111
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 9.8093 - mae: 9.8093
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 9.3257 - mae: 9.3257
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 8.8256 - mae: 8.8256
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 8.2839 - mae: 8.2839
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 7.6924 - mae: 7.6924
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 7.0456 - mae: 7.0456
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 6.3375 - mae: 6.3375
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 5.5616 - mae: 5.5616
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - loss: 4.7462 - mae: 4.7462
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 4.6360 - mae: 4.6360
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 4.5233 - mae: 4.5233
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 4.4079 - mae: 4.4079
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 4.4200 - mae: 4.4200
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - loss: 4.3355 - mae: 4.3355
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 4.3791 - mae: 4.3791
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 4.2928 - mae: 4.2928
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 4.3063 - mae: 4.3063
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 4.2508 - mae: 4.2508
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 4.2324 - mae: 4.2324
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 4.2080 - mae: 4.2080
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 4.1575 - mae: 4.1575
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 4.1644 - mae: 4.1644
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 4.0812 - mae: 4.0812
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 4.1196 - mae: 4.1196
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 4.0315 - mae: 4.0315
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 4.0447 - mae: 4.0447
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 3.9844 - mae: 3.9844
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 3.9649 - mae: 3.9649
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 3.9358 - mae: 3.9358
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - loss: 3.8831 - mae: 3.8831
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 3.8854 - mae: 3.8854
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 3.8066 - mae: 3.8066
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 3.8711 - mae: 3.8711
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 3.8108 - mae: 3.8108
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 3.8553 - mae: 3.8553
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 3.8220 - mae: 3.8220
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 3.8319 - mae: 3.8319
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 3.8299 - mae: 3.8299
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - loss: 3.8083 - mae: 3.8083
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 3.8378 - mae: 3.8378
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 3.7846 - mae: 3.7846
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 3.8459 - mae: 3.8459
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 3.7853 - mae: 3.7853
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 3.8328 - mae: 3.8328
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - loss: 3.7974 - mae: 3.7974
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 3.8091 - mae: 3.8091
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 3.8054 - mae: 3.8054
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 3.7853 - mae: 3.7853
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - loss: 3.8136 - mae: 3.8136
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 3.7613 - mae: 3.7613
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 3.8219 - mae: 3.8219
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 3.7613 - mae: 3.7613
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 3.8093 - mae: 3.8093
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 3.7739 - mae: 3.7739
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 3.7852 - mae: 3.7852
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 3.7821 - mae: 3.7821
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 3.7610 - mae: 3.7610
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 3.7905 - mae: 3.7905
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 3.7368 - mae: 3.7368
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 3.7989 - mae: 3.7989
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 3.7386 - mae: 3.7386
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 3.7833 - mae: 3.7833
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 3.7514 - mae: 3.7514
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 3.7599 - mae: 3.7599
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 3.7598 - mae: 3.7598
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 3.7355 - mae: 3.7355
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 3.7684 - mae: 3.7684
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 3.7109 - mae: 3.7109
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 3.7771 - mae: 3.7771
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 3.7171 - mae: 3.7171
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - loss: 3.7559 - mae: 3.7559
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 3.7300 - mae: 3.7300
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 3.7333 - mae: 3.7333
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 3.7386 - mae: 3.7386
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 3.7086 - mae: 3.7086
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 3.7474 - mae: 3.7474
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 3.6879 - mae: 3.6879
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 3.7511 - mae: 3.7511
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 3.6966 - mae: 3.6966
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 3.7271 - mae: 3.7271
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 3.7097 - mae: 3.7097
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 3.7054 - mae: 3.7054
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 3.7185 - mae: 3.7185
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 3.6804 - mae: 3.6804
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 3.7275 - mae: 3.7275
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - loss: 3.6683 - mae: 3.6683
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 3.7226 - mae: 3.7226
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 3.6771 - mae: 3.6771
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 3.6976 - mae: 3.6976
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 3.6889 - mae: 3.6889

# %%
#Make and plot predictions for model_1
y_preds_1 = model.predict(X_test)
plot_predictions(predictions=y_preds_1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 2
#       1 # Evaluate the model on the test set
# ----> 2 model.evaluate(X_test, y_test)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\progbar.py:119, in Progbar.update(self, current, values, finalize)
#     116     message += "\n"
#     118 if self.target is not None:
# --> 119     numdigits = int(math.log10(self.target)) + 1
#     120     bar = ("%" + str(numdigits) + "d/%d") % (current, self.target)
#     121     bar = f"\x1b{bar}\x1b "
#
# ValueError: math domain error

# %%
X, y

# %%
prediction = model.predict(np.array([[17.0]]))
print(prediction)

# %%
# Set random seed
tf.random.set_seed(42)
# Create a model (same as above)
model = tf.keras.Sequential([
tf.keras.layers.Dense(1)
])
# Compile model (same as above)
model.compile(loss=tf.keras.losses.mae,
optimizer=tf.keras.optimizers.SGD(),
metrics=["mae"])
# Fit model (this time we'll train for longer)
model.fit(tf.expand_dims(X, axis=-1), y, epochs=100) # train for 100 epochs not 10
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 22.1296 - mae: 22.1296
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 9.8926 - mae: 9.8926
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 11.5468 - mae: 11.5468
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 11.4914 - mae: 11.4914
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 11.1724 - mae: 11.1724
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 10.3725 - mae: 10.3725
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 9.9708 - mae: 9.9708
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 9.8843 - mae: 9.8843
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 9.7978 - mae: 9.7978
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 10.8595 - mae: 10.8595
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 9.8641 - mae: 9.8641
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 9.8416 - mae: 9.8416
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 9.8191 - mae: 9.8191
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 9.7965 - mae: 9.7965
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 9.7740 - mae: 9.7740
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 9.7515 - mae: 9.7515
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 9.7289 - mae: 9.7289
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 9.6061 - mae: 9.6061
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 11.3354 - mae: 11.3354
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 11.2801 - mae: 11.2801
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 11.2248 - mae: 11.2248
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 10.8893 - mae: 10.8893
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 10.0677 - mae: 10.0677
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 9.5744 - mae: 9.5744
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 9.6304 - mae: 9.6304
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 9.6078 - mae: 9.6078
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 9.5853 - mae: 9.5853
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 9.5628 - mae: 9.5628
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 9.5402 - mae: 9.5402
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 9.5177 - mae: 9.5177
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 9.4952 - mae: 9.4952
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 9.4727 - mae: 9.4727
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 9.4501 - mae: 9.4501
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 9.3244 - mae: 9.3244
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 11.1173 - mae: 11.1173
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 11.0620 - mae: 11.0620
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 11.0066 - mae: 11.0066
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 10.9513 - mae: 10.9513
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 10.6005 - mae: 10.6005
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 9.6502 - mae: 9.6502
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 9.3252 - mae: 9.3252
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 9.2387 - mae: 9.2387
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 10.1975 - mae: 10.1975
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 11.3891 - mae: 11.3891
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 12.0492 - mae: 12.0492
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 11.3769 - mae: 11.3769
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 12.0381 - mae: 12.0381
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 11.3647 - mae: 11.3647
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 12.0269 - mae: 12.0269
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 11.3525 - mae: 11.3525
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 12.0158 - mae: 12.0158
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 11.3403 - mae: 11.3403
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 12.0046 - mae: 12.0046
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 11.3281 - mae: 11.3281
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 11.9935 - mae: 11.9935
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 11.3159 - mae: 11.3159
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 11.9823 - mae: 11.9823
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 11.3037 - mae: 11.3037
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 11.9711 - mae: 11.9711
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 11.2916 - mae: 11.2916
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 11.9600 - mae: 11.9600
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 11.2794 - mae: 11.2794
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 11.9488 - mae: 11.9488
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 11.2672 - mae: 11.2672
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 11.9377 - mae: 11.9377
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 11.2550 - mae: 11.2550
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 11.9265 - mae: 11.9265
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 11.2428 - mae: 11.2428
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 11.9154 - mae: 11.9154
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 11.2306 - mae: 11.2306
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 11.9042 - mae: 11.9042
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 11.2184 - mae: 11.2184
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 11.8930 - mae: 11.8930
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 11.2062 - mae: 11.2062
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 11.8819 - mae: 11.8819
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 11.1940 - mae: 11.1940
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 11.8707 - mae: 11.8707
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 11.1818 - mae: 11.1818
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 11.8596 - mae: 11.8596
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 11.1697 - mae: 11.1697
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 11.8484 - mae: 11.8484
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 11.1575 - mae: 11.1575
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 11.8373 - mae: 11.8373
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 11.1453 - mae: 11.1453
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 11.8261 - mae: 11.8261
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 11.1331 - mae: 11.1331
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 11.8149 - mae: 11.8149
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 11.4404 - mae: 11.4404
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 10.4697 - mae: 10.4697
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 12.5207 - mae: 12.5207
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 10.9185 - mae: 10.9185
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 11.5763 - mae: 11.5763
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 10.9063 - mae: 10.9063
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 11.5652 - mae: 11.5652
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 10.8941 - mae: 10.8941
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 11.5540 - mae: 11.5540
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 10.8819 - mae: 10.8819
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 11.5428 - mae: 11.5428
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 10.8697 - mae: 10.8697
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 11.5317 - mae: 11.5317

# %%
X, y
# Out:
# (array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#          -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#          -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#           32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#           76,   80,   84,   88,   92,   96]),
#  array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#         -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#          14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#          66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106]))

# %%
prediction = model.predict(np.array([[17.0]]))
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# [[15.8637295]]

# %%
# Make a bigger dataset
X = np.arange(-100, 100, 4)
X
# Out:
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96])

# %%
# Make labels for the dataset (adhering to the same pattern as before)
y = np.arange(-90, 110, 4)
y
# Out:
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106])

# %%
print(len(X), len(y))
# Out:
# 50 50

# %%
# Split data into train and test sets
X_train = X[:40] # first 40 examples (80% of data)
y_train = y[:40]
X_test = X[40:] # last 10 examples (20% of data)
y_test = y[40:]
len(X_train), len(X_test)
# Out:
# (40, 10)

# %%
#plot shiiii
plt.figure(figsize=(10, 7))
# Plot training data in blue
plt.scatter(X_train, y_train, c='b', label='Training data')
# Plot test data in green
plt.scatter(X_test, y_test, c='g', label='Testing data')
# Show the legend
plt.legend();

# %%
# Set random seed
tf.random.set_seed(42)
# Create a model (same as above)
model = tf.keras.Sequential([
tf.keras.layers.Input(shape=(1,)),
tf.keras.layers.Dense(1) # define the input_shape to our model
])
# Compile model (same as above)
model.compile(loss=tf.keras.losses.mae,
optimizer=tf.keras.optimizers.SGD(),
metrics=["mae"])

# %%
# This will work after specifying the input shape
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                      │ (None, 1)                   │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit the model to the training data
model.fit(X_train, y_train, epochs=10, verbose=1) # verbose controls how much
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 7.6925 - mae: 7.6925
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 12.0533 - mae: 12.0533
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 8.2188 - mae: 8.2188
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 8.8728 - mae: 8.8728
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 7.8214 - mae: 7.8214
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 10.7878 - mae: 10.7878
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 7.6259 - mae: 7.6259
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 11.9605 - mae: 11.9605
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 8.1368 - mae: 8.1368
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 8.6820 - mae: 8.6820

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
# Make predictions
y_preds = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step

# %%
# View the predictions
X_test,y_test,y_preds
# Out:
# (array([60, 64, 68, 72, 76, 80, 84, 88, 92, 96]),
#  array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106]),
#  array([[50.02508 ],
#         [53.350586],
#         [56.67609 ],
#         [60.001595],
#         [63.327103],
#         [66.6526  ],
#         [69.97811 ],
#         [73.30362 ],
#         [76.62912 ],
#         [79.95463 ]], dtype=float32))

# %%
def plot_predictions(train_data=X_train,
    train_labels=y_train,
    test_data=X_test,
    test_labels=y_test,
    predictions=y_preds):
    """
    Plots training data, test data and compares predictions.
    """
    plt.figure(figsize=(10, 7))
    # Plot training data in blue
    plt.scatter(train_data, train_labels, c="b", label="Training data")
    # Plot test data in green
    plt.scatter(test_data, test_labels, c="g", label="Testing data")
    # Plot the predictions in red (predictions were made on the test data)
    plt.scatter(test_data, predictions, c="r", label="Predictions")
    # Show the legend
    plt.legend();

# %%
plot_predictions(train_data=X_train,
train_labels=y_train,
test_data=X_test,
test_labels=y_test,
predictions=y_preds)

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - loss: 20.0965 - mae: 20.0965
# [20.09646224975586, 20.09646224975586]

# %%
#model 1
# Set random seed
tf.random.set_seed(42)
# Replicate original model
model_1 = tf.keras.Sequential([
tf.keras.layers.Input(shape=(1,)),
tf.keras.layers.Dense(1)
])
# Compile the model
model_1.compile(loss=tf.keras.losses.mae,
optimizer=tf.keras.optimizers.SGD(0.01),
metrics=['mae'])
# Fit the model
model_1.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 74.3836 - mae: 74.3836
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 39.3457 - mae: 39.3457
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 9.2988 - mae: 9.2988
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 8.3363 - mae: 8.3363
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 9.0379 - mae: 9.0379
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 8.0352 - mae: 8.0352
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 9.7312 - mae: 9.7312
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 8.0173 - mae: 8.0173
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 9.7196 - mae: 9.7196
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 7.9995 - mae: 7.9995
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 9.7080 - mae: 9.7080
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 7.9816 - mae: 7.9816
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 9.6964 - mae: 9.6964
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 7.9638 - mae: 7.9638
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 9.6847 - mae: 9.6847
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 7.9459 - mae: 7.9459
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 9.6731 - mae: 9.6731
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 8.0531 - mae: 8.0531
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 8.5968 - mae: 8.5968
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 8.4635 - mae: 8.4635
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 8.2313 - mae: 8.2313
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 8.9751 - mae: 8.9751
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 8.0458 - mae: 8.0458
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 8.7143 - mae: 8.7143
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 7.6367 - mae: 7.6367
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 10.6557 - mae: 10.6557
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 7.4361 - mae: 7.4361
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 11.8381 - mae: 11.8381
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 7.9638 - mae: 7.9638
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 8.6258 - mae: 8.6258
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 7.5645 - mae: 7.5645
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 10.5631 - mae: 10.5631
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 7.3696 - mae: 7.3696
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 11.7452 - mae: 11.7452
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 7.8818 - mae: 7.8818
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 8.5373 - mae: 8.5373
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 7.4922 - mae: 7.4922
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 10.4706 - mae: 10.4706
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 7.3030 - mae: 7.3030
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 11.6524 - mae: 11.6524
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 7.6755 - mae: 7.6755
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 9.4170 - mae: 9.4170
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 7.7835 - mae: 7.7835
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 8.4356 - mae: 8.4356
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 7.4006 - mae: 7.4006
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 10.3695 - mae: 10.3695
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 7.2155 - mae: 7.2155
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 11.5526 - mae: 11.5526
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 7.5803 - mae: 7.5803
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 9.3150 - mae: 9.3150
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 7.5624 - mae: 7.5624
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 9.3034 - mae: 9.3034
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 7.5446 - mae: 7.5446
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 9.2918 - mae: 9.2918
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 7.6527 - mae: 7.6527
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 8.3075 - mae: 8.3075
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 7.2701 - mae: 7.2701
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 10.2514 - mae: 10.2514
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 7.0860 - mae: 7.0860
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 11.4390 - mae: 11.4390
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 7.4493 - mae: 7.4493
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 9.1898 - mae: 9.1898
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 7.4315 - mae: 7.4315
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 9.1782 - mae: 9.1782
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 7.4136 - mae: 7.4136
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 9.1665 - mae: 9.1665
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 7.5218 - mae: 7.5218
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 8.1795 - mae: 8.1795
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 7.1397 - mae: 7.1397
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 10.1334 - mae: 10.1334
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 6.9566 - mae: 6.9566
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 11.3253 - mae: 11.3253
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 7.3184 - mae: 7.3184
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 9.0645 - mae: 9.0645
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 7.3005 - mae: 7.3005
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 9.1345 - mae: 9.1345
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6.8531 - mae: 6.8531
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 9.5499 - mae: 9.5499
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 11.3230 - mae: 11.3230
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 12.0476 - mae: 12.0476
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 7.4095 - mae: 7.4095
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 8.0887 - mae: 8.0887
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 7.0059 - mae: 7.0059
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 10.0747 - mae: 10.0747
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6.8121 - mae: 6.8121
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 11.3421 - mae: 11.3421
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 6.7875 - mae: 6.7875
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 11.2603 - mae: 11.2603
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 6.6736 - mae: 6.6736
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 7.7319 - mae: 7.7319
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 9.2006 - mae: 9.2006
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 10.8879 - mae: 10.8879
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 7.8416 - mae: 7.8416
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 9.3104 - mae: 9.3104
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 11.0430 - mae: 11.0430
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 12.0820 - mae: 12.0820
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 7.3158 - mae: 7.3158
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 8.0351 - mae: 8.0351
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 7.0168 - mae: 7.0168
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 8.8302 - mae: 8.8302

# %%
# Make and plot predictions for model_1
y_preds_1 = model_1.predict(X_test)
plot_predictions(predictions=y_preds_1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step

# %%
# Evaluate the model on the test set
model_1.evaluate(X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - loss: 16.1393 - mae: 16.1393
# [16.139331817626953, 16.139331817626953]

# %%
import tensorflow as tf

# %%
#MODEL 2
# Set random seed
tf.random.set_seed(42)
# Replicate model_1 and add an extra layer
model_2 = tf.keras.Sequential([
tf.keras.layers.Input(shape=(1,)),
tf.keras.layers.Dense(1),
])
# Compile the model
model_2.compile(loss=tf.keras.losses.mae,
optimizer=tf.keras.optimizers.SGD(),
metrics=['mae'])
# Fit the model
model_2.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=150, verbose=2) #set verbose to 0 for less output
# Out:
# Epoch 1/150
# 2/2 - 1s - 486ms/step - loss: 35.5378 - mae: 35.5378
# Epoch 2/150
# 2/2 - 0s - 66ms/step - loss: 8.2028 - mae: 8.2028
# Epoch 3/150
# 2/2 - 0s - 81ms/step - loss: 9.8631 - mae: 9.8631
# Epoch 4/150
# 2/2 - 0s - 65ms/step - loss: 8.1841 - mae: 8.1841
# Epoch 5/150
# 2/2 - 0s - 84ms/step - loss: 9.8502 - mae: 9.8502
# Epoch 6/150
# 2/2 - 0s - 80ms/step - loss: 8.1654 - mae: 8.1654
# Epoch 7/150
# 2/2 - 0s - 66ms/step - loss: 9.8372 - mae: 9.8372
# Epoch 8/150
# 2/2 - 0s - 76ms/step - loss: 8.1467 - mae: 8.1467
# Epoch 9/150
# 2/2 - 0s - 83ms/step - loss: 9.8243 - mae: 9.8243
# Epoch 10/150
# 2/2 - 0s - 82ms/step - loss: 8.1280 - mae: 8.1280
# Epoch 11/150
# 2/2 - 0s - 69ms/step - loss: 9.8114 - mae: 9.8114
# Epoch 12/150
# 2/2 - 0s - 79ms/step - loss: 8.1093 - mae: 8.1093
# Epoch 13/150
# 2/2 - 0s - 86ms/step - loss: 9.7984 - mae: 9.7984
# Epoch 14/150
# 2/2 - 0s - 77ms/step - loss: 8.0907 - mae: 8.0907
# Epoch 15/150
# 2/2 - 0s - 73ms/step - loss: 9.7855 - mae: 9.7855
# Epoch 16/150
# 2/2 - 0s - 73ms/step - loss: 8.0720 - mae: 8.0720
# Epoch 17/150
# 2/2 - 0s - 81ms/step - loss: 9.7725 - mae: 9.7725
# Epoch 18/150
# 2/2 - 0s - 76ms/step - loss: 8.0533 - mae: 8.0533
# Epoch 19/150
# 2/2 - 0s - 78ms/step - loss: 9.7596 - mae: 9.7596
# Epoch 20/150
# 2/2 - 0s - 82ms/step - loss: 8.0346 - mae: 8.0346
# Epoch 21/150
# 2/2 - 0s - 82ms/step - loss: 9.7467 - mae: 9.7467
# Epoch 22/150
# 2/2 - 0s - 76ms/step - loss: 8.0159 - mae: 8.0159
# Epoch 23/150
# 2/2 - 0s - 77ms/step - loss: 9.7337 - mae: 9.7337
# Epoch 24/150
# 2/2 - 0s - 73ms/step - loss: 7.9972 - mae: 7.9972
# Epoch 25/150
# 2/2 - 0s - 73ms/step - loss: 9.7208 - mae: 9.7208
# Epoch 26/150
# 2/2 - 0s - 76ms/step - loss: 8.1669 - mae: 8.1669
# Epoch 27/150
# 2/2 - 0s - 83ms/step - loss: 8.8369 - mae: 8.8369
# Epoch 28/150
# 2/2 - 0s - 80ms/step - loss: 7.6830 - mae: 7.6830
# Epoch 29/150
# 2/2 - 0s - 77ms/step - loss: 10.6212 - mae: 10.6212
# Epoch 30/150
# 2/2 - 0s - 74ms/step - loss: 7.4406 - mae: 7.4406
# Epoch 31/150
# 2/2 - 0s - 73ms/step - loss: 11.6764 - mae: 11.6764
# Epoch 32/150
# 2/2 - 0s - 86ms/step - loss: 7.9048 - mae: 7.9048
# Epoch 33/150
# 2/2 - 0s - 76ms/step - loss: 9.6221 - mae: 9.6221
# Epoch 34/150
# 2/2 - 0s - 73ms/step - loss: 7.8861 - mae: 7.8861
# Epoch 35/150
# 2/2 - 0s - 72ms/step - loss: 9.6092 - mae: 9.6092
# Epoch 36/150
# 2/2 - 0s - 78ms/step - loss: 7.8674 - mae: 7.8674
# Epoch 37/150
# 2/2 - 0s - 73ms/step - loss: 9.5962 - mae: 9.5962
# Epoch 38/150
# 2/2 - 0s - 77ms/step - loss: 8.0372 - mae: 8.0372
# Epoch 39/150
# 2/2 - 0s - 76ms/step - loss: 8.7097 - mae: 8.7097
# Epoch 40/150
# 2/2 - 0s - 83ms/step - loss: 7.5536 - mae: 7.5536
# Epoch 41/150
# 2/2 - 0s - 77ms/step - loss: 10.5033 - mae: 10.5033
# Epoch 42/150
# 2/2 - 0s - 74ms/step - loss: 7.3122 - mae: 7.3122
# Epoch 43/150
# 2/2 - 0s - 82ms/step - loss: 11.5626 - mae: 11.5626
# Epoch 44/150
# 2/2 - 0s - 75ms/step - loss: 7.7750 - mae: 7.7750
# Epoch 45/150
# 2/2 - 0s - 79ms/step - loss: 9.4975 - mae: 9.4975
# Epoch 46/150
# 2/2 - 0s - 56ms/step - loss: 7.7563 - mae: 7.7563
# Epoch 47/150
# 2/2 - 0s - 61ms/step - loss: 9.4846 - mae: 9.4846
# Epoch 48/150
# 2/2 - 0s - 67ms/step - loss: 7.7376 - mae: 7.7376
# Epoch 49/150
# 2/2 - 0s - 93ms/step - loss: 9.4717 - mae: 9.4717
# Epoch 50/150
# 2/2 - 0s - 83ms/step - loss: 7.9074 - mae: 7.9074
# Epoch 51/150
# 2/2 - 0s - 48ms/step - loss: 8.5826 - mae: 8.5826
# Epoch 52/150
# 2/2 - 0s - 80ms/step - loss: 7.4243 - mae: 7.4243
# Epoch 53/150
# 2/2 - 0s - 85ms/step - loss: 10.3854 - mae: 10.3854
# Epoch 54/150
# 2/2 - 0s - 76ms/step - loss: 7.1837 - mae: 7.1837
# Epoch 55/150
# 2/2 - 0s - 77ms/step - loss: 11.4487 - mae: 11.4487
# Epoch 56/150
# 2/2 - 0s - 78ms/step - loss: 7.6452 - mae: 7.6452
# Epoch 57/150
# 2/2 - 0s - 77ms/step - loss: 9.3730 - mae: 9.3730
# Epoch 58/150
# 2/2 - 0s - 77ms/step - loss: 7.6265 - mae: 7.6265
# Epoch 59/150
# 2/2 - 0s - 76ms/step - loss: 9.3600 - mae: 9.3600
# Epoch 60/150
# 2/2 - 0s - 78ms/step - loss: 7.7949 - mae: 7.7949
# Epoch 61/150
# 2/2 - 0s - 92ms/step - loss: 8.4699 - mae: 8.4699
# Epoch 62/150
# 2/2 - 0s - 68ms/step - loss: 7.3150 - mae: 7.3150
# Epoch 63/150
# 2/2 - 0s - 78ms/step - loss: 10.2775 - mae: 10.2775
# Epoch 64/150
# 2/2 - 0s - 94ms/step - loss: 7.0769 - mae: 7.0769
# Epoch 65/150
# 2/2 - 0s - 156ms/step - loss: 11.3434 - mae: 11.3434
# Epoch 66/150
# 2/2 - 0s - 147ms/step - loss: 7.5340 - mae: 7.5340
# Epoch 67/150
# 2/2 - 0s - 65ms/step - loss: 9.2613 - mae: 9.2613
# Epoch 68/150
# 2/2 - 0s - 84ms/step - loss: 7.5153 - mae: 7.5153
# Epoch 69/150
# 2/2 - 0s - 74ms/step - loss: 9.2484 - mae: 9.2484
# Epoch 70/150
# 2/2 - 0s - 73ms/step - loss: 7.4967 - mae: 7.4967
# Epoch 71/150
# 2/2 - 0s - 77ms/step - loss: 9.3567 - mae: 9.3567
# Epoch 72/150
# 2/2 - 0s - 75ms/step - loss: 6.9306 - mae: 6.9306
# Epoch 73/150
# 2/2 - 0s - 80ms/step - loss: 9.4686 - mae: 9.4686
# Epoch 74/150
# 2/2 - 0s - 77ms/step - loss: 11.0330 - mae: 11.0330
# Epoch 75/150
# 2/2 - 0s - 70ms/step - loss: 11.9874 - mae: 11.9874
# Epoch 76/150
# 2/2 - 0s - 80ms/step - loss: 7.6588 - mae: 7.6588
# Epoch 77/150
# 2/2 - 0s - 86ms/step - loss: 8.3564 - mae: 8.3564
# Epoch 78/150
# 2/2 - 0s - 78ms/step - loss: 7.1562 - mae: 7.1562
# Epoch 79/150
# 2/2 - 0s - 80ms/step - loss: 10.1981 - mae: 10.1981
# Epoch 80/150
# 2/2 - 0s - 76ms/step - loss: 6.9067 - mae: 6.9067
# Epoch 81/150
# 2/2 - 0s - 77ms/step - loss: 11.3678 - mae: 11.3678
# Epoch 82/150
# 2/2 - 0s - 85ms/step - loss: 6.8861 - mae: 6.8861
# Epoch 83/150
# 2/2 - 0s - 69ms/step - loss: 11.2944 - mae: 11.2944
# Epoch 84/150
# 2/2 - 0s - 76ms/step - loss: 6.7306 - mae: 6.7306
# Epoch 85/150
# 2/2 - 0s - 75ms/step - loss: 8.0641 - mae: 8.0641
# Epoch 86/150
# 2/2 - 0s - 80ms/step - loss: 9.1735 - mae: 9.1735
# Epoch 87/150
# 2/2 - 0s - 71ms/step - loss: 10.6108 - mae: 10.6108
# Epoch 88/150
# 2/2 - 0s - 70ms/step - loss: 8.1400 - mae: 8.1400
# Epoch 89/150
# 2/2 - 0s - 79ms/step - loss: 9.2494 - mae: 9.2494
# Epoch 90/150
# 2/2 - 0s - 68ms/step - loss: 10.7530 - mae: 10.7530
# Epoch 91/150
# 2/2 - 0s - 78ms/step - loss: 11.9976 - mae: 11.9976
# Epoch 92/150
# 2/2 - 0s - 76ms/step - loss: 7.5508 - mae: 7.5508
# Epoch 93/150
# 2/2 - 0s - 69ms/step - loss: 8.2854 - mae: 8.2854
# Epoch 94/150
# 2/2 - 0s - 69ms/step - loss: 7.2214 - mae: 7.2214
# Epoch 95/150
# 2/2 - 0s - 79ms/step - loss: 9.0624 - mae: 9.0624
# Epoch 96/150
# 2/2 - 0s - 77ms/step - loss: 6.9776 - mae: 6.9776
# Epoch 97/150
# 2/2 - 0s - 81ms/step - loss: 10.3916 - mae: 10.3916
# Epoch 98/150
# 2/2 - 0s - 67ms/step - loss: 7.9639 - mae: 7.9639
# Epoch 99/150
# 2/2 - 0s - 71ms/step - loss: 9.0733 - mae: 9.0733
# Epoch 100/150
# 2/2 - 0s - 71ms/step - loss: 10.5213 - mae: 10.5213
# Epoch 101/150
# 2/2 - 0s - 75ms/step - loss: 8.0398 - mae: 8.0398
# Epoch 102/150
# 2/2 - 0s - 70ms/step - loss: 9.1492 - mae: 9.1492
# Epoch 103/150
# 2/2 - 0s - 80ms/step - loss: 10.6793 - mae: 10.6793
# Epoch 104/150
# 2/2 - 0s - 71ms/step - loss: 11.8187 - mae: 11.8187
# Epoch 105/150
# 2/2 - 0s - 77ms/step - loss: 7.3866 - mae: 7.3866
# Epoch 106/150
# 2/2 - 0s - 70ms/step - loss: 8.1106 - mae: 8.1106
# Epoch 107/150
# 2/2 - 0s - 84ms/step - loss: 7.0649 - mae: 7.0649
# Epoch 108/150
# 2/2 - 0s - 78ms/step - loss: 8.7632 - mae: 8.7632
# Epoch 109/150
# 2/2 - 0s - 69ms/step - loss: 7.0463 - mae: 7.0463
# Epoch 110/150
# 2/2 - 0s - 86ms/step - loss: 8.8714 - mae: 8.8714
# Epoch 111/150
# 2/2 - 0s - 74ms/step - loss: 6.8272 - mae: 6.8272
# Epoch 112/150
# 2/2 - 0s - 78ms/step - loss: 10.2748 - mae: 10.2748
# Epoch 113/150
# 2/2 - 0s - 77ms/step - loss: 7.8393 - mae: 7.8393
# Epoch 114/150
# 2/2 - 0s - 71ms/step - loss: 8.9487 - mae: 8.9487
# Epoch 115/150
# 2/2 - 0s - 85ms/step - loss: 10.4044 - mae: 10.4044
# Epoch 116/150
# 2/2 - 0s - 80ms/step - loss: 7.9152 - mae: 7.9152
# Epoch 117/150
# 2/2 - 0s - 77ms/step - loss: 9.0246 - mae: 9.0246
# Epoch 118/150
# 2/2 - 0s - 69ms/step - loss: 10.5768 - mae: 10.5768
# Epoch 119/150
# 2/2 - 0s - 56ms/step - loss: 11.6326 - mae: 11.6326
# Epoch 120/150
# 2/2 - 0s - 80ms/step - loss: 7.2051 - mae: 7.2051
# Epoch 121/150
# 2/2 - 0s - 80ms/step - loss: 7.9213 - mae: 7.9213
# Epoch 122/150
# 2/2 - 0s - 63ms/step - loss: 6.6928 - mae: 6.6928
# Epoch 123/150
# 2/2 - 0s - 77ms/step - loss: 9.9102 - mae: 9.9102
# Epoch 124/150
# 2/2 - 0s - 71ms/step - loss: 7.4841 - mae: 7.4841
# Epoch 125/150
# 2/2 - 0s - 71ms/step - loss: 8.5935 - mae: 8.5935
# Epoch 126/150
# 2/2 - 0s - 78ms/step - loss: 9.9177 - mae: 9.9177
# Epoch 127/150
# 2/2 - 0s - 88ms/step - loss: 7.5600 - mae: 7.5600
# Epoch 128/150
# 2/2 - 0s - 83ms/step - loss: 8.6693 - mae: 8.6693
# Epoch 129/150
# 2/2 - 0s - 72ms/step - loss: 10.0473 - mae: 10.0473
# Epoch 130/150
# 2/2 - 0s - 69ms/step - loss: 7.6358 - mae: 7.6358
# Epoch 131/150
# 2/2 - 0s - 77ms/step - loss: 8.7452 - mae: 8.7452
# Epoch 132/150
# 2/2 - 0s - 80ms/step - loss: 10.1770 - mae: 10.1770
# Epoch 133/150
# 2/2 - 0s - 84ms/step - loss: 7.7117 - mae: 7.7117
# Epoch 134/150
# 2/2 - 0s - 80ms/step - loss: 8.8211 - mae: 8.8211
# Epoch 135/150
# 2/2 - 0s - 72ms/step - loss: 10.3282 - mae: 10.3282
# Epoch 136/150
# 2/2 - 0s - 81ms/step - loss: 7.3961 - mae: 7.3961
# Epoch 137/150
# 2/2 - 0s - 82ms/step - loss: 8.5055 - mae: 8.5055
# Epoch 138/150
# 2/2 - 0s - 77ms/step - loss: 9.8418 - mae: 9.8418
# Epoch 139/150
# 2/2 - 0s - 72ms/step - loss: 7.4720 - mae: 7.4720
# Epoch 140/150
# 2/2 - 0s - 76ms/step - loss: 8.5814 - mae: 8.5814
# Epoch 141/150
# 2/2 - 0s - 73ms/step - loss: 9.9714 - mae: 9.9714
# Epoch 142/150
# 2/2 - 0s - 85ms/step - loss: 7.5479 - mae: 7.5479
# Epoch 143/150
# 2/2 - 0s - 72ms/step - loss: 8.6572 - mae: 8.6572
# Epoch 144/150
# 2/2 - 0s - 77ms/step - loss: 10.1010 - mae: 10.1010
# Epoch 145/150
# 2/2 - 0s - 74ms/step - loss: 7.6237 - mae: 7.6237
# Epoch 146/150
# 2/2 - 0s - 70ms/step - loss: 8.7331 - mae: 8.7331
# Epoch 147/150
# 2/2 - 0s - 74ms/step - loss: 10.2748 - mae: 10.2748
# Epoch 148/150
# 2/2 - 0s - 79ms/step - loss: 7.3081 - mae: 7.3081
# Epoch 149/150
# 2/2 - 0s - 84ms/step - loss: 8.4175 - mae: 8.4175
# Epoch 150/150
# 2/2 - 0s - 74ms/step - loss: 9.7659 - mae: 9.7659

# %%
model_2.evaluate(X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - loss: 12.9480 - mae: 12.9480
# [12.947957038879395, 12.947957038879395]

# %%
# Make and plot predictions for model_2
y_preds_2 = model_2.predict(X_test)
plot_predictions(predictions=y_preds_2)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000015746EAA200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
